# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scienceplots
import shap

import events_package.utils as utils
from events_package.Experiment import Experiment
from events_package.config import FIVE_LAYERS
from events_package.input_getters import get_Y_1, get_X_1, get_X_2

# %%
Experiment.__version__
# Out:
# '5.0'

# %% [markdown]
# # 1. Importing Single Particle Data

# %% [markdown]
# ## 1.1 Electrons

# %%
# importing data
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\Electron\Parquet\1m_electron_pq_3"
)

electrons = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
electrons.length
# Out:
# 444840

# %%
electrons.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 434998
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 434998

# %% [markdown]
# ## 1.2 Photons

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\Photon\Parquet\1m_photon_pq"
)

photons = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
photons.length
# Out:
# 444142

# %%
photons.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 434870
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 434870

# %% [markdown]
# ## 1.3 Neutral Pions

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\PiZero\Parquet\pq_pi0_2"
)

pi0 = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
pi0.length
# Out:
# 412856

# %%
pi0.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 391483
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 391483

# %% [markdown]
# ## 1.4 Charged Pions

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\PiPlusMinus\Parquet\pq_piplusminus_2"
)

pi_char = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
pi_char.length
# Out:
# 357554

# %%
pi_char.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 330809
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 330803

# %% [markdown]
# # 2. Model With Input Features Version 1

# %%
# hyperparameters used
params = {
    "objective": "reg:squarederror",
    "max_depth": 6,
    "learning_rate": 0.18,
    "colsample_bytree": 0.8,
    "eval_metric": "rmse",
    "n_estimators": 600,
}

# %%
print(get_X_1.__doc__)
# Out:
#     Creates inputs for model training.
#     Inputs include center etas, differences between center etas from different layers, and all energy information.
#     All energy info means that all cells are passed as inputs in consistent ordering, without making any normalisations or changes.
#     This type of model has all the information necessary to make predictions, but the inputs are not optimised in any way.
#     Each single input is an array of 312 values (for single particle events).

# %%
# split electron data into training and testing, next train XGBoost model
electrons.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(electrons.X_test.shape)

electrons.train_xgboost_model(params)
# Out:
# (87000, 312)
# INFO: Trained XGBoost model; mean squared error: 1399.408423379894
# 1399.408423379894

# %%
# split photon data into training and testing, next train XGBoost model
photons.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(photons.X_test.shape)

photons.train_xgboost_model(params)
# Out:
# (86975, 312)
# INFO: Trained XGBoost model; mean squared error: 1486.9185939471365
# 1486.9185939471365

# %%
# split neutral pion data into training and testing, next train XGBoost model
pi0.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(pi0.X_test.shape)

pi0.train_xgboost_model(params)
# Out:
# (78297, 312)
# INFO: Trained XGBoost model; mean squared error: 3053.5482601338167
# 3053.5482601338167

# %%
# split charged pion data into training and testing, next train XGBoost model
pi_char.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(pi_char.X_test.shape)

pi_char.train_xgboost_model(params)
# Out:
# (66161, 312)
# INFO: Trained XGBoost model; mean squared error: 9179.373302859436
# 9179.373302859436

# %% [markdown]
# # 3 Model With Input Features Version 2

# %%
print(get_X_2.__doc__)
# Out:
#     Creates inputs for model training.
#     Inputs include center etas, differences between center etas from different layers, and some energy information.
#     Compared to get_X_2, this time a sum over phi axis is taken from calorimeter cell windows.
#     The reasoning behind this is that the regression problem of finding z is independent of phi.
#     This procedure greately decreases number of inputs, without any accuracy loss.
#     Each single input is an array of 62 values (for single particle events).

# %%
# split electron data into training and testing, next train XGBoost model
electrons.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(electrons.X_test.shape)

electrons.train_xgboost_model(params)
# Out:
# (87000, 62)
# INFO: Trained XGBoost model; mean squared error: 1352.5041306973285
# 1352.5041306973285

# %%
# split photon data into training and testing, next train XGBoost model
photons.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(photons.X_test.shape)

photons.train_xgboost_model(params)
# Out:
# (86975, 62)
# INFO: Trained XGBoost model; mean squared error: 1436.7863637333537
# 1436.7863637333537

# %%
# split neutral pion data into training and testing, next train XGBoost model
pi0.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(pi0.X_test.shape)

pi0.train_xgboost_model(params)
# Out:
# (78297, 62)
# INFO: Trained XGBoost model; mean squared error: 2988.789870055645
# 2988.789870055645

# %%
# split charged pion data into training and testing, next train XGBoost model
pi_char.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(pi_char.X_test.shape)

pi_char.train_xgboost_model(params)
# Out:
# (66161, 62)
# INFO: Trained XGBoost model; mean squared error: 9007.713932503315
# 9007.713932503315

# %% [markdown]
# # 4. Hyperparameter Scan For Input Features Version 2

# %%
max_depth_range = [6, 7]
learning_rate_range = [0.18, 0.19]
colsample_bytree_range = [0.8, 0.9, 1.0]
num_rounds_grid = [500, 600, 700, 800]

# Generate all combinations of hyperparameters
param_combinations = list(
    itertools.product(
        max_depth_range, learning_rate_range, colsample_bytree_range, num_rounds_grid
    )
)

# Construct the param_grid
param_grid = [
    {
        "objective": "reg:squarederror",
        "max_depth": max_depth,
        "learning_rate": learning_rate,
        "colsample_bytree": colsample_bytree,
        "n_estimators": n_estimators,
    }
    for max_depth, learning_rate, colsample_bytree, n_estimators in param_combinations
]


# Perform hyperparameter scan
electrons_hyperparams = electrons.xgboost_hyperparameter_scan(
    param_grid, nodes_info=True
)

photons_hyperparams = photons.xgboost_hyperparameter_scan(param_grid, nodes_info=True)

pi0_hyperparams = pi0.xgboost_hyperparameter_scan(param_grid, nodes_info=True)

pi_char_hyperparams = pi_char.xgboost_hyperparameter_scan(param_grid, nodes_info=True)
# Out:
# INFO: Trained XGBoost model; mean squared error: 1369.3177678287109
# INFO: Trained XGBoost model; mean squared error: 1352.5041306973285
# INFO: Trained XGBoost model; mean squared error: 1342.9511925721413
# INFO: Trained XGBoost model; mean squared error: 1333.0176377128073
# INFO: Trained XGBoost model; mean squared error: 1370.0152532402865
# INFO: Trained XGBoost model; mean squared error: 1352.5684490170045
# INFO: Trained XGBoost model; mean squared error: 1341.7616150550773
# INFO: Trained XGBoost model; mean squared error: 1334.5750847765974
# INFO: Trained XGBoost model; mean squared error: 1370.9426941770419
# INFO: Trained XGBoost model; mean squared error: 1355.0550787893312
# INFO: Trained XGBoost model; mean squared error: 1343.8513777144035
# INFO: Trained XGBoost model; mean squared error: 1335.739659951696
# INFO: Trained XGBoost model; mean squared error: 1373.8040377965933
# INFO: Trained XGBoost model; mean squared error: 1358.181949744477
# INFO: Trained XGBoost model; mean squared error: 1348.7436728608109
# INFO: Trained XGBoost model; mean squared error: 8997.864014035682
# INFO: Trained XGBoost model; mean squared error: 9009.892374179823
# INFO: Trained XGBoost model; mean squared error: 9018.506062650875
# INFO: Trained XGBoost model; mean squared error: 9026.260348318894
# INFO: Trained XGBoost model; mean squared error: 9031.185742141683
# INFO: Trained XGBoost model; mean squared error: 9046.198771712867
# INFO: Trained XGBoost model; mean squared error: 8976.429122234713
# INFO: Trained XGBoost model; mean squared error: 8977.14001222758
# INFO: Trained XGBoost model; mean squared error: 8986.767791003214
# INFO: Trained XGBoost model; mean squared error: 9005.246659417939
# INFO: Trained XGBoost model; mean squared error: 9013.058579398454
# INFO: Trained XGBoost model; mean squared error: 9013.699911515647
# INFO: Trained XGBoost model; mean squared error: 9032.642966551639
# INFO: Trained XGBoost model; mean squared error: 9045.470226225805
# INFO: Trained XGBoost model; mean squared error: 9003.63969878542
# INFO: Trained XGBoost model; mean squared error: 9022.424129443243
# INFO: Trained XGBoost model; mean squared error: 9032.119300831102
# INFO: Trained XGBoost model; mean squared error: 9039.295940163958
# INFO: Trained XGBoost model; mean squared error: 8999.085876373361
# INFO: Trained XGBoost model; mean squared error: 8998.339305958827
# INFO: Trained XGBoost model; mean squared error: 9001.676114542513
# INFO: Trained XGBoost model; mean squared error: 9005.297595460852

# %%
electrons_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 3   1333.017638  reg:squarederror          6           0.18               0.8
# 7   1334.575085  reg:squarederror          6           0.18               0.9
# 11  1335.739660  reg:squarederror          6           0.18               1.0
# 39  1337.635752  reg:squarederror          7           0.19               0.8
# 15  1339.829827  reg:squarederror          6           0.19               0.8
# 31  1340.429725  reg:squarederror          7           0.18               0.9
# 38  1340.626789  reg:squarederror          7           0.19               0.8
# 35  1340.884862  reg:squarederror          7           0.18               1.0
# 6   1341.761615  reg:squarederror          6           0.18               0.9
# 2   1342.951193  reg:squarederror          6           0.18               0.8
# 27  1343.121848  reg:squarederror          7           0.18               0.8
# 30  1343.592601  reg:squarederror          7           0.18               0.9
# 10  1343.851378  reg:squarederror          6           0.18               1.0
# 19  1344.219194  reg:squarederror          6           0.19               0.9
# 37  1344.277038  reg:squarederror          7           0.19               0.8
# 34  1344.648974  reg:squarederror          7           0.18               1.0
# 26  1346.013470  reg:squarederror          7           0.18               0.8
# 23  1346.771616  reg:squarederror          6           0.19               1.0
# 33  1348.277822  reg:squarederror          7           0.18               1.0
# 29  1348.498629  reg:squarederror          7           0.18               0.9
# 14  1348.743673  reg:squarederror          6           0.19               0.8
# 46  1349.457019  reg:squarederror          7           0.19               1.0
# 36  1350.054832  reg:squarederror          7           0.19               0.8
# 47  1350.787363  reg:squarederror          7           0.19               1.0
# 25  1351.273731  reg:squarederror          7           0.18               0.8
# 18  1351.879937  reg:squarederror          6           0.19               0.9
# 22  1352.131987  reg:squarederror          6           0.19               1.0
# 1   1352.504131  reg:squarederror          6           0.18               0.8
# 5   1352.568449  reg:squarederror          6           0.18               0.9
# 28  1354.065979  reg:squarederror          7           0.18               0.9
# 45  1354.393306  reg:squarederror          7           0.19               1.0
# 9   1355.055079  reg:squarederror          6           0.18               1.0
# 24  1356.815237  reg:squarederror          7           0.18               0.8
# 32  1357.105234  reg:squarederror          7           0.18               1.0
# 13  1358.181950  reg:squarederror          6           0.19               0.8
# 43  1360.912150  reg:squarederror          7           0.19               0.9
# 44  1360.941109  reg:squarederror          7           0.19               1.0
# 17  1361.816561  reg:squarederror          6           0.19               0.9
# 42  1362.508424  reg:squarederror          7           0.19               0.9
# 21  1363.729710  reg:squarederror          6           0.19               1.0
# 41  1364.338256  reg:squarederror          7           0.19               0.9
# 0   1369.317768  reg:squarederror          6           0.18               0.8
# 4   1370.015253  reg:squarederror          6           0.18               0.9
# 8   1370.942694  reg:squarederror          6           0.18               1.0
# 40  1371.652941  reg:squarederror          7           0.19               0.9
# 12  1373.804038  reg:squarederror          6           0.19               0.8
# 16  1377.040875  reg:squarederror          6           0.19               0.9
# 20  1378.092046  reg:squarederror          6           0.19               1.0
#
#     n_estimators  Nodes NO
# 3            800     47825
# 7            800     47824
# 11           800     47871
# 39           800     90693
# 15           800     48011
# 31           800     91067
# 38           700     80003
# 35           800     90109
# 6            700     41995
# 2            700     42014
# 27           800     91507
# 30           700     80188
# 10           700     42087
# 19           800     47802
# 37           600     68999
# 34           700     79216
# 26           700     80497
# 23           800     47786
# 33           600     68750
# 29           600     68998
# 14           700     42127
# 46           700     79232
# 36           500     58202
# 47           800     90139
# 25           600     69440
# 18           700     41983
# 22           700     41993
# 1            600     36337
# 5            600     36260
# 28           500     58134
# 45           600     68113
# 9            600     36106
# 24           500     58562
# 32           500     57717
# 13           600     36238
# 43           800     89824
# 44           500     57317
# 17           600     36153
# 42           700     79031
# 21           600     36200
# 41           600     68344
# 0            500     30526
# 4            500     30471
# 8            500     30243
# 40           500     57491
# 12           500     30355
# 16           500     30347
# 20           500     30341

# %%
photons_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 11  1391.292465  reg:squarederror          6           0.18               1.0
# 7   1398.696472  reg:squarederror          6           0.18               0.9
# 27  1398.904562  reg:squarederror          7           0.18               0.8
# 19  1399.382518  reg:squarederror          6           0.19               0.9
# 15  1402.699328  reg:squarederror          6           0.19               0.8
# 35  1403.071541  reg:squarederror          7           0.18               1.0
# 31  1404.389515  reg:squarederror          7           0.18               0.9
# 26  1404.680308  reg:squarederror          7           0.18               0.8
# 39  1404.714792  reg:squarederror          7           0.19               0.8
# 23  1405.011497  reg:squarederror          6           0.19               1.0
# 3   1406.743077  reg:squarederror          6           0.18               0.8
# 30  1406.898542  reg:squarederror          7           0.18               0.9
# 34  1406.902954  reg:squarederror          7           0.18               1.0
# 10  1407.418489  reg:squarederror          6           0.18               1.0
# 43  1408.108993  reg:squarederror          7           0.19               0.9
# 18  1408.710956  reg:squarederror          6           0.19               0.9
# 38  1408.778008  reg:squarederror          7           0.19               0.8
# 47  1410.109662  reg:squarederror          7           0.19               1.0
# 6   1410.322663  reg:squarederror          6           0.18               0.9
# 42  1411.239567  reg:squarederror          7           0.19               0.9
# 25  1411.770221  reg:squarederror          7           0.18               0.8
# 14  1412.475967  reg:squarederror          6           0.19               0.8
# 46  1412.885030  reg:squarederror          7           0.19               1.0
# 33  1413.165003  reg:squarederror          7           0.18               1.0
# 37  1414.759162  reg:squarederror          7           0.19               0.8
# 22  1415.111900  reg:squarederror          6           0.19               1.0
# 29  1415.517310  reg:squarederror          7           0.18               0.9
# 45  1419.632853  reg:squarederror          7           0.19               1.0
# 2   1419.651810  reg:squarederror          6           0.18               0.8
# 41  1420.480991  reg:squarederror          7           0.19               0.9
# 9   1421.577967  reg:squarederror          6           0.18               1.0
# 24  1424.491059  reg:squarederror          7           0.18               0.8
# 32  1425.509187  reg:squarederror          7           0.18               1.0
# 36  1425.862820  reg:squarederror          7           0.19               0.8
# 5   1426.628194  reg:squarederror          6           0.18               0.9
# 17  1427.423961  reg:squarederror          6           0.19               0.9
# 28  1427.948146  reg:squarederror          7           0.18               0.9
# 13  1428.735746  reg:squarederror          6           0.19               0.8
# 40  1430.776506  reg:squarederror          7           0.19               0.9
# 21  1431.322207  reg:squarederror          6           0.19               1.0
# 44  1431.574731  reg:squarederror          7           0.19               1.0
# 1   1436.786364  reg:squarederror          6           0.18               0.8
# 8   1446.443129  reg:squarederror          6           0.18               1.0
# 16  1448.675637  reg:squarederror          6           0.19               0.9
# 4   1449.932567  reg:squarederror          6           0.18               0.9
# 12  1452.464192  reg:squarederror          6           0.19               0.8
# 20  1453.120523  reg:squarederror          6           0.19               1.0
# 0   1460.696215  reg:squarederror          6           0.18               0.8
#
#     n_estimators  Nodes NO
# 11           800     47359
# 7            800     47424
# 27           800     90642
# 19           800     47202
# 15           800     47538
# 35           800     89585
# 31           800     89416
# 26           700     79645
# 39           800     90643
# 23           800     47146
# 3            800     47737
# 30           700     79116
# 34           700     78672
# 10           700     41566
# 43           800     89448
# 18           700     41531
# 38           700     79783
# 47           800     88731
# 6            700     41593
# 42           700     78529
# 25           600     68803
# 14           700     41813
# 46           700     77788
# 33           600     68139
# 37           600     69035
# 22           700     41558
# 29           600     68193
# 45           600     67161
# 2            700     41907
# 41           600     67925
# 9            600     35818
# 24           500     57864
# 32           500     57098
# 36           500     58122
# 5            600     35868
# 17           600     35814
# 28           500     57299
# 13           600     35937
# 40           500     57038
# 21           600     35811
# 44           500     56357
# 1            600     36198
# 8            500     30067
# 16           500     30043
# 4            500     30042
# 12           500     30058
# 20           500     30032
# 0            500     30355

# %%
pi0_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 27  2874.710473  reg:squarederror          7           0.18               0.8
# 39  2882.107084  reg:squarederror          7           0.19               0.8
# 26  2887.087193  reg:squarederror          7           0.18               0.8
# 47  2888.409479  reg:squarederror          7           0.19               1.0
# 31  2889.616198  reg:squarederror          7           0.18               0.9
# 35  2890.521389  reg:squarederror          7           0.18               1.0
# 38  2893.363886  reg:squarederror          7           0.19               0.8
# 43  2898.066641  reg:squarederror          7           0.19               0.9
# 46  2902.846788  reg:squarederror          7           0.19               1.0
# 34  2903.179431  reg:squarederror          7           0.18               1.0
# 30  2904.105867  reg:squarederror          7           0.18               0.9
# 25  2906.445527  reg:squarederror          7           0.18               0.8
# 42  2907.178437  reg:squarederror          7           0.19               0.9
# 37  2913.691073  reg:squarederror          7           0.19               0.8
# 45  2919.764153  reg:squarederror          7           0.19               1.0
# 33  2919.889289  reg:squarederror          7           0.18               1.0
# 15  2921.303133  reg:squarederror          6           0.19               0.8
# 29  2922.389981  reg:squarederror          7           0.18               0.9
# 23  2922.410128  reg:squarederror          6           0.19               1.0
# 41  2925.808536  reg:squarederror          7           0.19               0.9
# 7   2926.775913  reg:squarederror          6           0.18               0.9
# 3   2926.787960  reg:squarederror          6           0.18               0.8
# 19  2927.283268  reg:squarederror          6           0.19               0.9
# 36  2934.174452  reg:squarederror          7           0.19               0.8
# 24  2935.692443  reg:squarederror          7           0.18               0.8
# 11  2935.796981  reg:squarederror          6           0.18               1.0
# 14  2946.084304  reg:squarederror          6           0.19               0.8
# 22  2948.018292  reg:squarederror          6           0.19               1.0
# 32  2948.289863  reg:squarederror          7           0.18               1.0
# 28  2949.339024  reg:squarederror          7           0.18               0.9
# 40  2950.868710  reg:squarederror          7           0.19               0.9
# 18  2951.460646  reg:squarederror          6           0.19               0.9
# 44  2951.655995  reg:squarederror          7           0.19               1.0
# 2   2956.189066  reg:squarederror          6           0.18               0.8
# 6   2958.874854  reg:squarederror          6           0.18               0.9
# 10  2964.797823  reg:squarederror          6           0.18               1.0
# 13  2981.633177  reg:squarederror          6           0.19               0.8
# 17  2982.325598  reg:squarederror          6           0.19               0.9
# 21  2982.347482  reg:squarederror          6           0.19               1.0
# 5   2985.773354  reg:squarederror          6           0.18               0.9
# 1   2988.789870  reg:squarederror          6           0.18               0.8
# 9   2999.008824  reg:squarederror          6           0.18               1.0
# 16  3026.070295  reg:squarederror          6           0.19               0.9
# 20  3028.505549  reg:squarederror          6           0.19               1.0
# 12  3029.117338  reg:squarederror          6           0.19               0.8
# 4   3032.710875  reg:squarederror          6           0.18               0.9
# 0   3038.888437  reg:squarederror          6           0.18               0.8
# 8   3046.885577  reg:squarederror          6           0.18               1.0
#
#     n_estimators  Nodes NO
# 27           800     89596
# 39           800     89850
# 26           700     78832
# 47           800     88848
# 31           800     89221
# 35           800     88970
# 38           700     78987
# 43           800     88740
# 46           700     78396
# 34           700     78108
# 30           700     78545
# 25           600     68096
# 42           700     78197
# 37           600     68114
# 45           600     67859
# 33           600     67777
# 15           800     47385
# 29           600     67825
# 23           800     46928
# 41           600     67336
# 7            800     47240
# 3            800     47352
# 19           800     47195
# 36           500     57476
# 24           500     57055
# 11           800     47093
# 14           700     41625
# 22           700     41341
# 32           500     56829
# 28           500     56897
# 40           500     56757
# 18           700     41370
# 44           500     56821
# 2            700     41568
# 6            700     41392
# 10           700     41432
# 13           600     35829
# 17           600     35636
# 21           600     35584
# 5            600     35702
# 1            600     35826
# 9            600     35684
# 16           500     29932
# 20           500     29863
# 12           500     30049
# 4            500     29979
# 0            500     29941
# 8            500     29876

# %%
pi_char_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 18  8959.147102  reg:squarederror          6           0.19               0.9
# 10  8961.867258  reg:squarederror          6           0.18               1.0
# 11  8962.586405  reg:squarederror          6           0.18               1.0
# 22  8964.976521  reg:squarederror          6           0.19               1.0
# 19  8966.851516  reg:squarederror          6           0.19               0.9
# 23  8969.947562  reg:squarederror          6           0.19               1.0
# 9   8974.537239  reg:squarederror          6           0.18               1.0
# 17  8976.059672  reg:squarederror          6           0.19               0.9
# 32  8976.429122  reg:squarederror          7           0.18               1.0
# 33  8977.140012  reg:squarederror          7           0.18               1.0
# 14  8981.607763  reg:squarederror          6           0.19               0.8
# 3   8981.745377  reg:squarederror          6           0.18               0.8
# 6   8982.454864  reg:squarederror          6           0.18               0.9
# 15  8983.572493  reg:squarederror          6           0.19               0.8
# 13  8984.504092  reg:squarederror          6           0.19               0.8
# 7   8985.564949  reg:squarederror          6           0.18               0.9
# 34  8986.767791  reg:squarederror          7           0.18               1.0
# 21  8987.537726  reg:squarederror          6           0.19               1.0
# 5   8987.793810  reg:squarederror          6           0.18               0.9
# 2   8992.710821  reg:squarederror          6           0.18               0.8
# 25  8994.036443  reg:squarederror          7           0.18               0.8
# 24  8996.283878  reg:squarederror          7           0.18               0.8
# 26  8997.864014  reg:squarederror          7           0.18               0.8
# 45  8998.339306  reg:squarederror          7           0.19               1.0
# 12  8998.570287  reg:squarederror          6           0.19               0.8
# 44  8999.085876  reg:squarederror          7           0.19               1.0
# 16  8999.893515  reg:squarederror          6           0.19               0.9
# 46  9001.676115  reg:squarederror          7           0.19               1.0
# 40  9003.639699  reg:squarederror          7           0.19               0.9
# 35  9005.246659  reg:squarederror          7           0.18               1.0
# 47  9005.297595  reg:squarederror          7           0.19               1.0
# 1   9007.713933  reg:squarederror          6           0.18               0.8
# 27  9009.892374  reg:squarederror          7           0.18               0.8
# 20  9010.250925  reg:squarederror          6           0.19               1.0
# 8   9012.309275  reg:squarederror          6           0.18               1.0
# 36  9013.058579  reg:squarederror          7           0.19               0.8
# 0   9013.616663  reg:squarederror          6           0.18               0.8
# 37  9013.699912  reg:squarederror          7           0.19               0.8
# 4   9014.346602  reg:squarederror          6           0.18               0.9
# 28  9018.506063  reg:squarederror          7           0.18               0.9
# 41  9022.424129  reg:squarederror          7           0.19               0.9
# 29  9026.260348  reg:squarederror          7           0.18               0.9
# 30  9031.185742  reg:squarederror          7           0.18               0.9
# 42  9032.119301  reg:squarederror          7           0.19               0.9
# 38  9032.642967  reg:squarederror          7           0.19               0.8
# 43  9039.295940  reg:squarederror          7           0.19               0.9
# 39  9045.470226  reg:squarederror          7           0.19               0.8
# 31  9046.198772  reg:squarederror          7           0.18               0.9
#
#     n_estimators  Nodes NO
# 18           700     40788
# 10           700     40436
# 11           800     46276
# 22           700     40530
# 19           800     46548
# 23           800     46335
# 9            600     34844
# 17           600     34871
# 32           500     54337
# 33           600     65203
# 14           700     40521
# 3            800     46601
# 6            700     40723
# 15           800     46268
# 13           600     34812
# 7            800     46505
# 34           700     75911
# 21           600     34743
# 5            600     34898
# 2            700     40734
# 25           600     64587
# 24           500     54199
# 26           700     75631
# 45           600     64746
# 12           500     28993
# 44           500     54000
# 16           500     29025
# 46           700     75773
# 40           500     53912
# 35           800     86924
# 47           800     86733
# 1            600     34984
# 27           800     86642
# 20           500     28991
# 8            500     29080
# 36           500     54122
# 0            500     29201
# 37           600     64974
# 4            500     29061
# 28           500     54359
# 41           600     64675
# 29           600     65318
# 30           700     76246
# 42           700     75478
# 38           700     76011
# 43           800     86416
# 39           800     86899
# 31           800     87257
