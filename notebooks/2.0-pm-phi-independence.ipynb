# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scienceplots
import shap

import events_package.utils as utils
from events_package.Experiment import Experiment
from events_package.config import FIVE_LAYERS
from events_package.input_getters import get_Y_1, get_X_1, get_X_2

# %%
Experiment.__version__
# Out:
# '5.0'

# %% [markdown]
# # 1. Importing Single Particle Data

# %% [markdown]
# ## 1.1 Electrons

# %%
# importing data
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\Electron\Parquet\1m_electron_pq_3"
)

electrons = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
electrons.length
# Out:
# 444840

# %%
electrons.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 434998
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 434998

# %% [markdown]
# ## 1.2 Photons

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\Photon\Parquet\1m_photon_pq"
)

photons = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
photons.length
# Out:
# 444142

# %%
photons.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 434870
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 434870

# %% [markdown]
# ## 1.3 Neutral Pions

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\PiZero\Parquet\pq_pi0_2"
)

pi0 = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
pi0.length
# Out:
# 412856

# %%
pi0.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 391483
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 391483

# %% [markdown]
# ## 1.4 Charged Pions

# %%
dataset_df = pd.read_parquet(
    r"C:\Users\User1\Desktop\MSci_Project\Data\6_data\PiPlusMinus\Parquet\pq_piplusminus_2"
)

pi_char = Experiment(dataset_df, config=FIVE_LAYERS)
del dataset_df
pi_char.length
# Out:
# 357554

# %%
pi_char.standard_procedure()
# Out:
# INFO: Removed duplicates
# INFO: Denoisified the dataset
# INFO: Shuffled dataset
# INFO: Number of events after removing duplicates: 330809
# INFO: Removed events with 0 energy in layers after denoisifying
# INFO: Number of events after removing 0 energy (in calorimeters) events: 330809

# %% [markdown]
# # 2. Model With Input Features Version 1

# %%
# hyperparameters used
params = {
    "objective": "reg:squarederror",
    "max_depth": 6,
    "learning_rate": 0.18,
    "colsample_bytree": 0.8,
    "eval_metric": "rmse",
    "n_estimators": 600,
}

# %%
print(get_X_1.__doc__)
# Out:
#     Creates inputs for model training.
#     Inputs include center etas, differences between center etas from different layers, and all energy information.
#     All energy info means that all cells are passed as inputs in consistent ordering, without making any normalisations or changes.
#     This type of model has all the information necessary to make predictions, but the inputs are not optimised in any way.
#     Each single input is an array of 312 values (for single particle events).

# %%
# split electron data into training and testing, next train XGBoost model
electrons.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(electrons.X_test.shape)

electrons.train_xgboost_model(params)  # 1399.408423379894
# Out:
# (87000, 312)
# INFO: Trained XGBoost model; mean squared error: 1396.6998859688572
# 1396.6998859688572

# %%
# split photon data into training and testing, next train XGBoost model
photons.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(photons.X_test.shape)

photons.train_xgboost_model(params)
# Out:
# (86975, 312)
# INFO: Trained XGBoost model; mean squared error: 1492.748128110236
# 1492.748128110236

# %%
# split neutral pion data into training and testing, next train XGBoost model
pi0.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(pi0.X_test.shape)

pi0.train_xgboost_model(params)
# Out:
# (78297, 312)
# INFO: Trained XGBoost model; mean squared error: 3080.561237892581
# 3080.561237892581

# %%
# split charged pion data into training and testing, next train XGBoost model
pi_char.train_test_split(get_X=get_X_1, get_Y=get_Y_1, test_size=0.2)
print(pi_char.X_test.shape)

pi_char.train_xgboost_model(params)  # 9179.373302859436
# Out:
# (66162, 312)
# INFO: Trained XGBoost model; mean squared error: 9116.682579837692
# 9116.682579837692

# %% [markdown]
# # 3 Model With Input Features Version 2

# %%
print(get_X_2.__doc__)
# Out:
#     Creates inputs for model training.
#     Inputs include center etas, differences between center etas from different layers, and some energy information.
#     Compared to get_X_2, this time a sum over phi axis is taken from calorimeter cell windows.
#     The reasoning behind this is that the regression problem of finding z is independent of phi.
#     This procedure greately decreases number of inputs, without any accuracy loss.
#     Each single input is an array of 62 values (for single particle events).

# %%
# split electron data into training and testing, next train XGBoost model
electrons.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(electrons.X_test.shape)

electrons.train_xgboost_model(params)
# Out:
# (87000, 62)
# INFO: Trained XGBoost model; mean squared error: 1336.2376481022725
# 1336.2376481022725

# %%
# split photon data into training and testing, next train XGBoost model
photons.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(photons.X_test.shape)

photons.train_xgboost_model(params)
# Out:
# (86975, 62)
# INFO: Trained XGBoost model; mean squared error: 1417.4439615546664
# 1417.4439615546664

# %%
# split neutral pion data into training and testing, next train XGBoost model
pi0.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(pi0.X_test.shape)

pi0.train_xgboost_model(params)
# Out:
# (78297, 62)
# INFO: Trained XGBoost model; mean squared error: 2980.5483081668035
# 2980.5483081668035

# %%
# split charged pion data into training and testing, next train XGBoost model
pi_char.train_test_split(get_X=get_X_2, get_Y=get_Y_1, test_size=0.2)
print(pi_char.X_test.shape)

pi_char.train_xgboost_model(params)
# Out:
# (66162, 62)
# INFO: Trained XGBoost model; mean squared error: 8885.947316904048
# 8885.947316904048

# %% [markdown]
# # 4. Hyperparameter Scan For Input Features Version 2

# %%
max_depth_range = [6, 7]
learning_rate_range = [0.18, 0.19]
colsample_bytree_range = [0.8, 0.9, 1.0]
num_rounds_grid = [500, 600, 700, 800]

# Generate all combinations of hyperparameters
param_combinations = list(
    itertools.product(
        max_depth_range, learning_rate_range, colsample_bytree_range, num_rounds_grid
    )
)

# Construct the param_grid
param_grid = [
    {
        "objective": "reg:squarederror",
        "max_depth": max_depth,
        "learning_rate": learning_rate,
        "colsample_bytree": colsample_bytree,
        "n_estimators": n_estimators,
    }
    for max_depth, learning_rate, colsample_bytree, n_estimators in param_combinations
]


# Perform hyperparameter scan
electrons_hyperparams = electrons.xgboost_hyperparameter_scan(
    param_grid, nodes_info=True
)

photons_hyperparams = photons.xgboost_hyperparameter_scan(param_grid, nodes_info=True)

pi0_hyperparams = pi0.xgboost_hyperparameter_scan(param_grid, nodes_info=True)

pi_char_hyperparams = pi_char.xgboost_hyperparameter_scan(param_grid, nodes_info=True)
# Out:
# INFO: Trained XGBoost model; mean squared error: 1352.4761014183414
# INFO: Trained XGBoost model; mean squared error: 1336.2376481022725
# INFO: Trained XGBoost model; mean squared error: 1325.9025317502255
# INFO: Trained XGBoost model; mean squared error: 1320.3198177685297
# INFO: Trained XGBoost model; mean squared error: 1351.7911469985884
# INFO: Trained XGBoost model; mean squared error: 1336.7741900252968
# INFO: Trained XGBoost model; mean squared error: 1330.0130813009575
# INFO: Trained XGBoost model; mean squared error: 1324.3713109461487
# INFO: Trained XGBoost model; mean squared error: 1349.094380702262
# INFO: Trained XGBoost model; mean squared error: 1332.8962864524717
# INFO: Trained XGBoost model; mean squared error: 1325.718402949834
# INFO: Trained XGBoost model; mean squared error: 1320.0297822033626
# INFO: Trained XGBoost model; mean squared error: 1356.7184789721396
# INFO: Trained XGBoost model; mean squared error: 1341.7746681418969
# INFO: Trained XGBoost model; mean squared error: 1332.0765697546547
# INFO: Trained XGBoost model; mean squared error: 1325.3789312094475
# INFO: Trained XGBoost model; mean squared error: 1351.8629105810687
# INFO: Trained XGBoost model; mean squared error: 1336.8606192987497
# INFO: Trained XGBoost model; mean squared error: 1328.036956947526
# INFO: Trained XGBoost model; mean squared error: 1322.8636152217075
# INFO: Trained XGBoost model; mean squared error: 1350.3443151147185
# INFO: Trained XGBoost model; mean squared error: 1335.1702328492202
# INFO: Trained XGBoost model; mean squared error: 1326.5908942617075
# INFO: Trained XGBoost model; mean squared error: 9006.257249427137
# INFO: Trained XGBoost model; mean squared error: 9035.658309214612
# INFO: Trained XGBoost model; mean squared error: 9011.127903408318
# INFO: Trained XGBoost model; mean squared error: 9029.211397818775
# INFO: Trained XGBoost model; mean squared error: 9052.155423818756
# INFO: Trained XGBoost model; mean squared error: 9062.236065505533
# INFO: Trained XGBoost model; mean squared error: 9015.120395737778
# INFO: Trained XGBoost model; mean squared error: 9042.568478762409
# INFO: Trained XGBoost model; mean squared error: 9050.526426062632
# INFO: Trained XGBoost model; mean squared error: 9070.769227907786
# INFO: Trained XGBoost model; mean squared error: 8979.411747755985
# INFO: Trained XGBoost model; mean squared error: 8993.498447613842
# INFO: Trained XGBoost model; mean squared error: 9008.948555448791
# INFO: Trained XGBoost model; mean squared error: 9041.999563131445

# %%
electrons_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 11  1320.029782  reg:squarederror          6           0.18               1.0
# 3   1320.319818  reg:squarederror          6           0.18               0.8
# 19  1322.863615  reg:squarederror          6           0.19               0.9
# 23  1322.910953  reg:squarederror          6           0.19               1.0
# 7   1324.371311  reg:squarederror          6           0.18               0.9
# 15  1325.378931  reg:squarederror          6           0.19               0.8
# 10  1325.718403  reg:squarederror          6           0.18               1.0
# 2   1325.902532  reg:squarederror          6           0.18               0.8
# 22  1326.590894  reg:squarederror          6           0.19               1.0
# 18  1328.036957  reg:squarederror          6           0.19               0.9
# 6   1330.013081  reg:squarederror          6           0.18               0.9
# 14  1332.076570  reg:squarederror          6           0.19               0.8
# 9   1332.896286  reg:squarederror          6           0.18               1.0
# 21  1335.170233  reg:squarederror          6           0.19               1.0
# 1   1336.237648  reg:squarederror          6           0.18               0.8
# 5   1336.774190  reg:squarederror          6           0.18               0.9
# 27  1336.860029  reg:squarederror          7           0.18               0.8
# 17  1336.860619  reg:squarederror          6           0.19               0.9
# 26  1338.188428  reg:squarederror          7           0.18               0.8
# 42  1339.298286  reg:squarederror          7           0.19               0.9
# 25  1339.892976  reg:squarederror          7           0.18               0.8
# 43  1340.249917  reg:squarederror          7           0.19               0.9
# 41  1340.625845  reg:squarederror          7           0.19               0.9
# 33  1340.927007  reg:squarederror          7           0.18               1.0
# 31  1341.741001  reg:squarederror          7           0.18               0.9
# 13  1341.774668  reg:squarederror          6           0.19               0.8
# 38  1341.904006  reg:squarederror          7           0.19               0.8
# 24  1342.269023  reg:squarederror          7           0.18               0.8
# 39  1342.321609  reg:squarederror          7           0.19               0.8
# 34  1342.533917  reg:squarederror          7           0.18               1.0
# 30  1342.763021  reg:squarederror          7           0.18               0.9
# 37  1342.901571  reg:squarederror          7           0.19               0.8
# 35  1342.903101  reg:squarederror          7           0.18               1.0
# 29  1343.703236  reg:squarederror          7           0.18               0.9
# 36  1344.523935  reg:squarederror          7           0.19               0.8
# 40  1344.681564  reg:squarederror          7           0.19               0.9
# 32  1346.006793  reg:squarederror          7           0.18               1.0
# 8   1349.094381  reg:squarederror          6           0.18               1.0
# 45  1349.193664  reg:squarederror          7           0.19               1.0
# 28  1349.828872  reg:squarederror          7           0.18               0.9
# 20  1350.344315  reg:squarederror          6           0.19               1.0
# 46  1350.376473  reg:squarederror          7           0.19               1.0
# 4   1351.791147  reg:squarederror          6           0.18               0.9
# 16  1351.862911  reg:squarederror          6           0.19               0.9
# 47  1351.889045  reg:squarederror          7           0.19               1.0
# 44  1351.890842  reg:squarederror          7           0.19               1.0
# 0   1352.476101  reg:squarederror          6           0.18               0.8
# 12  1356.718479  reg:squarederror          6           0.19               0.8
#
#     n_estimators  Nodes NO
# 11           800     48721
# 3            800     48816
# 19           800     48691
# 23           800     48675
# 7            800     48841
# 15           800     48976
# 10           700     42616
# 2            700     42746
# 22           700     42605
# 18           700     42667
# 6            700     42766
# 14           700     42916
# 9            600     36581
# 21           600     36611
# 1            600     36763
# 5            600     36793
# 27           800     94082
# 17           600     36688
# 26           700     82434
# 42           700     83208
# 25           600     70818
# 43           800     94832
# 41           600     71398
# 33           600     71092
# 31           800     94333
# 13           600     36838
# 38           700     83219
# 24           500     59302
# 39           800     94938
# 34           700     82783
# 30           700     82900
# 37           600     71527
# 35           800     94478
# 29           600     71301
# 36           500     59898
# 40           500     59716
# 32           500     59426
# 8            500     30519
# 45           600     70960
# 28           500     59655
# 20           500     30520
# 46           700     82534
# 4            500     30747
# 16           500     30741
# 47           800     94160
# 44           500     59262
# 0            500     30753
# 12           500     30775

# %%
photons_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 11  1391.456087  reg:squarederror          6           0.18               1.0
# 3   1394.895423  reg:squarederror          6           0.18               0.8
# 27  1398.466366  reg:squarederror          7           0.18               0.8
# 7   1398.505271  reg:squarederror          6           0.18               0.9
# 19  1399.972179  reg:squarederror          6           0.19               0.9
# 26  1400.173207  reg:squarederror          7           0.18               0.8
# 15  1401.842966  reg:squarederror          6           0.19               0.8
# 25  1402.992199  reg:squarederror          7           0.18               0.8
# 10  1403.168539  reg:squarederror          6           0.18               1.0
# 2   1403.196762  reg:squarederror          6           0.18               0.8
# 35  1403.863039  reg:squarederror          7           0.18               1.0
# 23  1404.450084  reg:squarederror          6           0.19               1.0
# 39  1406.497424  reg:squarederror          7           0.19               0.8
# 6   1406.526487  reg:squarederror          6           0.18               0.9
# 34  1406.969994  reg:squarederror          7           0.18               1.0
# 38  1407.136642  reg:squarederror          7           0.19               0.8
# 18  1407.455091  reg:squarederror          6           0.19               0.9
# 43  1409.044174  reg:squarederror          7           0.19               0.9
# 37  1409.463658  reg:squarederror          7           0.19               0.8
# 42  1410.067009  reg:squarederror          7           0.19               0.9
# 14  1410.529464  reg:squarederror          6           0.19               0.8
# 33  1412.082786  reg:squarederror          7           0.18               1.0
# 31  1412.352419  reg:squarederror          7           0.18               0.9
# 24  1413.247880  reg:squarederror          7           0.18               0.8
# 22  1413.727542  reg:squarederror          6           0.19               1.0
# 41  1414.055901  reg:squarederror          7           0.19               0.9
# 30  1414.694766  reg:squarederror          7           0.18               0.9
# 36  1417.330401  reg:squarederror          7           0.19               0.8
# 1   1417.443962  reg:squarederror          6           0.18               0.8
# 9   1417.787459  reg:squarederror          6           0.18               1.0
# 29  1418.672474  reg:squarederror          7           0.18               0.9
# 32  1420.103626  reg:squarederror          7           0.18               1.0
# 17  1420.104500  reg:squarederror          6           0.19               0.9
# 40  1421.682440  reg:squarederror          7           0.19               0.9
# 5   1422.005852  reg:squarederror          6           0.18               0.9
# 13  1425.176293  reg:squarederror          6           0.19               0.8
# 28  1425.749513  reg:squarederror          7           0.18               0.9
# 46  1426.952638  reg:squarederror          7           0.19               1.0
# 47  1427.118826  reg:squarederror          7           0.19               1.0
# 21  1428.232559  reg:squarederror          6           0.19               1.0
# 45  1432.820147  reg:squarederror          7           0.19               1.0
# 16  1437.781560  reg:squarederror          6           0.19               0.9
# 8   1437.809283  reg:squarederror          6           0.18               1.0
# 44  1439.243615  reg:squarederror          7           0.19               1.0
# 0   1441.689272  reg:squarederror          6           0.18               0.8
# 4   1441.716085  reg:squarederror          6           0.18               0.9
# 12  1442.998335  reg:squarederror          6           0.19               0.8
# 20  1450.922618  reg:squarederror          6           0.19               1.0
#
#     n_estimators  Nodes NO
# 11           800     48536
# 3            800     48571
# 27           800     94384
# 7            800     48497
# 19           800     48611
# 26           700     82705
# 15           800     48678
# 25           600     71143
# 10           700     42542
# 2            700     42625
# 35           800     94369
# 23           800     48570
# 39           800     94414
# 6            700     42494
# 34           700     82709
# 38           700     82684
# 18           700     42627
# 43           800     94013
# 37           600     71048
# 42           700     82588
# 14           700     42681
# 33           600     70952
# 31           800     94189
# 24           500     59739
# 22           700     42504
# 41           600     71204
# 30           700     82516
# 36           500     59520
# 1            600     36634
# 9            600     36519
# 29           600     71047
# 32           500     59326
# 17           600     36571
# 40           500     59578
# 5            600     36456
# 13           600     36700
# 28           500     59402
# 46           700     82326
# 47           800     94076
# 21           600     36507
# 45           600     70671
# 16           500     30567
# 8            500     30575
# 44           500     59117
# 0            500     30589
# 4            500     30482
# 12           500     30711
# 20           500     30380

# %%
pi0_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 31  2892.679394  reg:squarederror          7           0.18               0.9
# 27  2897.641006  reg:squarederror          7           0.18               0.8
# 43  2903.345755  reg:squarederror          7           0.19               0.9
# 30  2905.565329  reg:squarederror          7           0.18               0.9
# 26  2909.283377  reg:squarederror          7           0.18               0.8
# 35  2910.025408  reg:squarederror          7           0.18               1.0
# 39  2913.777640  reg:squarederror          7           0.19               0.8
# 42  2916.102536  reg:squarederror          7           0.19               0.9
# 29  2919.275644  reg:squarederror          7           0.18               0.9
# 34  2920.975817  reg:squarederror          7           0.18               1.0
# 38  2921.853211  reg:squarederror          7           0.19               0.8
# 19  2922.375416  reg:squarederror          6           0.19               0.9
# 25  2923.196643  reg:squarederror          7           0.18               0.8
# 47  2923.612637  reg:squarederror          7           0.19               1.0
# 11  2923.744081  reg:squarederror          6           0.18               1.0
# 15  2924.639775  reg:squarederror          6           0.19               0.8
# 41  2926.877106  reg:squarederror          7           0.19               0.9
# 46  2930.284569  reg:squarederror          7           0.19               1.0
# 7   2932.272588  reg:squarederror          6           0.18               0.9
# 23  2933.115821  reg:squarederror          6           0.19               1.0
# 37  2936.582625  reg:squarederror          7           0.19               0.8
# 33  2936.720923  reg:squarederror          7           0.18               1.0
# 28  2937.193078  reg:squarederror          7           0.18               0.9
# 3   2937.329681  reg:squarederror          6           0.18               0.8
# 18  2942.617280  reg:squarederror          6           0.19               0.9
# 45  2944.642902  reg:squarederror          7           0.19               1.0
# 14  2947.240319  reg:squarederror          6           0.19               0.8
# 24  2948.073996  reg:squarederror          7           0.18               0.8
# 40  2949.991735  reg:squarederror          7           0.19               0.9
# 6   2950.159943  reg:squarederror          6           0.18               0.9
# 10  2951.011226  reg:squarederror          6           0.18               1.0
# 32  2952.444467  reg:squarederror          7           0.18               1.0
# 22  2953.495831  reg:squarederror          6           0.19               1.0
# 2   2954.112773  reg:squarederror          6           0.18               0.8
# 36  2957.574341  reg:squarederror          7           0.19               0.8
# 44  2968.084820  reg:squarederror          7           0.19               1.0
# 17  2970.001104  reg:squarederror          6           0.19               0.9
# 5   2972.272426  reg:squarederror          6           0.18               0.9
# 13  2977.919755  reg:squarederror          6           0.19               0.8
# 9   2979.984315  reg:squarederror          6           0.18               1.0
# 1   2980.548308  reg:squarederror          6           0.18               0.8
# 21  2984.083036  reg:squarederror          6           0.19               1.0
# 16  3012.089462  reg:squarederror          6           0.19               0.9
# 12  3015.403265  reg:squarederror          6           0.19               0.8
# 4   3015.720697  reg:squarederror          6           0.18               0.9
# 0   3016.784789  reg:squarederror          6           0.18               0.8
# 20  3018.629706  reg:squarederror          6           0.19               1.0
# 8   3024.599788  reg:squarederror          6           0.18               1.0
#
#     n_estimators  Nodes NO
# 31           800     93274
# 27           800     93188
# 43           800     93277
# 30           700     81843
# 26           700     81474
# 35           800     93415
# 39           800     93553
# 42           700     81629
# 29           600     70328
# 34           700     81835
# 38           700     81893
# 19           800     48131
# 25           600     69961
# 47           800     92735
# 11           800     48416
# 15           800     48519
# 41           600     69956
# 46           700     81213
# 7            800     48344
# 23           800     48313
# 37           600     70378
# 33           600     70185
# 28           500     58966
# 3            800     48455
# 18           700     42145
# 45           600     69619
# 14           700     42494
# 24           500     58444
# 40           500     58399
# 6            700     42412
# 10           700     42373
# 32           500     58696
# 22           700     42315
# 2            700     42501
# 36           500     58863
# 44           500     58239
# 17           600     36168
# 5            600     36472
# 13           600     36525
# 9            600     36399
# 1            600     36518
# 21           600     36365
# 16           500     30224
# 12           500     30491
# 4            500     30455
# 0            500     30536
# 20           500     30427
# 8            500     30454

# %%
pi_char_hyperparams.sort_values(by="MSE")
# Out:
#             MSE         objective  max_depth  learning_rate  colsample_bytree  \
# 1   8885.947317  reg:squarederror          6           0.18               0.8
# 2   8887.299902  reg:squarederror          6           0.18               0.8
# 0   8891.007720  reg:squarederror          6           0.18               0.8
# 3   8892.868615  reg:squarederror          6           0.18               0.8
# 14  8920.102867  reg:squarederror          6           0.19               0.8
# 6   8920.971214  reg:squarederror          6           0.18               0.9
# 5   8922.502803  reg:squarederror          6           0.18               0.9
# 13  8929.499214  reg:squarederror          6           0.19               0.8
# 15  8933.966574  reg:squarederror          6           0.19               0.8
# 7   8934.119881  reg:squarederror          6           0.18               0.9
# 28  8934.501384  reg:squarederror          7           0.18               0.9
# 4   8934.728023  reg:squarederror          6           0.18               0.9
# 9   8939.442887  reg:squarederror          6           0.18               1.0
# 11  8940.153935  reg:squarederror          6           0.18               1.0
# 18  8940.252286  reg:squarederror          6           0.19               0.9
# 10  8942.542073  reg:squarederror          6           0.18               1.0
# 12  8942.772150  reg:squarederror          6           0.19               0.8
# 29  8943.717079  reg:squarederror          7           0.18               0.9
# 19  8949.838712  reg:squarederror          6           0.19               0.9
# 24  8951.373578  reg:squarederror          7           0.18               0.8
# 30  8953.980974  reg:squarederror          7           0.18               0.9
# 17  8957.726178  reg:squarederror          6           0.19               0.9
# 25  8961.560169  reg:squarederror          7           0.18               0.8
# 31  8965.331154  reg:squarederror          7           0.18               0.9
# 26  8965.827873  reg:squarederror          7           0.18               0.8
# 23  8966.762814  reg:squarederror          6           0.19               1.0
# 22  8968.088150  reg:squarederror          6           0.19               1.0
# 21  8971.234783  reg:squarederror          6           0.19               1.0
# 16  8971.353832  reg:squarederror          6           0.19               0.9
# 32  8971.559368  reg:squarederror          7           0.18               1.0
# 8   8973.348431  reg:squarederror          6           0.18               1.0
# 44  8979.411748  reg:squarederror          7           0.19               1.0
# 20  8980.669185  reg:squarederror          6           0.19               1.0
# 33  8984.211104  reg:squarederror          7           0.18               1.0
# 27  8986.053787  reg:squarederror          7           0.18               0.8
# 45  8993.498448  reg:squarederror          7           0.19               1.0
# 34  9006.257249  reg:squarederror          7           0.18               1.0
# 46  9008.948555  reg:squarederror          7           0.19               1.0
# 36  9011.127903  reg:squarederror          7           0.19               0.8
# 40  9015.120396  reg:squarederror          7           0.19               0.9
# 37  9029.211398  reg:squarederror          7           0.19               0.8
# 35  9035.658309  reg:squarederror          7           0.18               1.0
# 47  9041.999563  reg:squarederror          7           0.19               1.0
# 41  9042.568479  reg:squarederror          7           0.19               0.9
# 42  9050.526426  reg:squarederror          7           0.19               0.9
# 38  9052.155424  reg:squarederror          7           0.19               0.8
# 39  9062.236066  reg:squarederror          7           0.19               0.8
# 43  9070.769228  reg:squarederror          7           0.19               0.9
#
#     n_estimators  Nodes NO
# 1            600     36019
# 2            700     42106
# 0            500     30031
# 3            800     48131
# 14           700     42046
# 6            700     42141
# 5            600     36073
# 13           600     35973
# 15           800     48135
# 7            800     48175
# 28           500     57511
# 4            500     30025
# 9            600     36075
# 11           800     48240
# 18           700     41910
# 10           700     42155
# 12           500     29959
# 29           600     69181
# 19           800     47824
# 24           500     57703
# 30           700     80954
# 17           600     35858
# 25           600     69389
# 31           800     92900
# 26           700     81003
# 23           800     48106
# 22           700     42018
# 21           600     35953
# 16           500     29861
# 32           500     57436
# 8            500     30036
# 44           500     57653
# 20           500     29941
# 33           600     69243
# 27           800     92635
# 45           600     69367
# 34           700     81033
# 46           700     81126
# 36           500     58081
# 40           500     58090
# 37           600     69707
# 35           800     92923
# 47           800     93095
# 41           600     69430
# 42           700     81324
# 38           700     81557
# 39           800     93421
# 43           800     93066

# %%
utils.save_table_df(
    dataframe=electrons_hyperparams.sort_values(by="MSE"),
    filename="2.0-electrons-hyperparams.csv",
)

# %%
utils.save_table_df(
    dataframe=photons_hyperparams.sort_values(by="MSE"),
    filename="2.0-photons-hyperparams.csv",
)

# %%
utils.save_table_df(
    dataframe=pi0_hyperparams.sort_values(by="MSE"), filename="2.0-pi0-hyperparams.csv"
)

# %%
utils.save_table_df(
    dataframe=pi_char_hyperparams.sort_values(by="MSE"),
    filename="2.0-pi_char-hyperparams.csv",
)
